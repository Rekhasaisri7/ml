# %%
import pandas as a
import numpy as n
import warnings
warnings.filterwarnings("ignore")

# %%
data=a.read_csv('documents/rainfall_in_india_1901-2015.csv',sep=",")
#data=data.fillna(data.mean())
#data.info()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %%
display(data)
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data1=data.drop('SUBDIVISION',axis=1)

# %%
display(data1)
# Out:
#       YEAR   JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0     1901  49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1  332.6
# 1     1902   0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7  666.2
# 2     1903  12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7  339.0
# 3     1904   9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1  820.4
# 4     1905   1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5  297.0
# ...    ...   ...    ...   ...    ...    ...    ...    ...    ...    ...
# 4111  2011   5.1    2.8   3.1   85.9  107.2  153.6  350.2  254.0  255.2
# 4112  2012  19.2    0.1   1.6   76.8   21.2  327.0  231.5  381.2  179.8
# 4113  2013  26.2   34.4  37.5    5.3   88.3  426.2  296.4  154.4  180.0
# 4114  2014  53.2   16.1   4.4   14.9   57.4  244.1  116.1  466.1  132.2
# 4115  2015   2.2    0.5   3.7   87.1  133.1  296.6  257.5  146.4  160.4
#
#         OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# ...

# %%
data2=data1.fillna(data1.mean())

# %%
data3=data2.isnull().sum()

# %%
display(data3)
# Out:
# YEAR       0
# JAN        0
# FEB        0
# MAR        0
# APR        0
# MAY        0
# JUN        0
# JUL        0
# AUG        0
# SEP        0
# OCT        0
# NOV        0
# DEC        0
# ANNUAL     0
# Jan-Feb    0
# Mar-May    0
# Jun-Sep    0
# Oct-Dec    0
# dtype: int64

# %%
data4=data.fillna(data3.mean())

# %%
display(data4)
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data4.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
data4.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4116.000000  4116.000000  4116.000000  4116.000000
# mean   1958.218659    18.938897    21.789431    27.319315    43.085520
# std      33.140898    33.574242    35.901220    46.936787    67.811512
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.600000
# 75%    1987.000000    22.125000    26.800000    31.225000    49.825000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4116.000000  4116.000000  4116.000000  4116.000000  4116.000000
# mean     85.682920   229.954762   346.623834   289.981414   197.074223
# std     123.211711   234.705204   269.690148   188.895403   135.518992
# ...

# %%
data4.hist(figsize=(24,24));

# %%
data.groupby("YEAR").sum()['ANNUAL'].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='YEAR'>

# %%
data5=data4.groupby(["YEAR"]).count()

# %%
display(data5)
# Out:
#       SUBDIVISION  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  SEP  OCT  NOV  DEC  \
# YEAR
# 1901           35   35   35   35   35   35   35   35   35   35   35   35   35
# 1902           35   35   35   35   35   35   35   35   35   35   35   35   35
# 1903           35   35   35   35   35   35   35   35   35   35   35   35   35
# 1904           35   35   35   35   35   35   35   35   35   35   35   35   35
# 1905           35   35   35   35   35   35   35   35   35   35   35   35   35
# ...           ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 2011           36   36   36   36   36   36   36   36   36   36   36   36   36
# 2012           36   36   36   36   36   36   36   36   36   36   36   36   36
# 2013           36   36   36   36   36   36   36   36   36   36   36   36   36
# 2014           36   36   36   36   36   36   36   36   36   36   36   36   36
# 2015           36   36   36   36   36   36   36   36   36   36   36   36   36
#
# ...

# %%
data6=a.get_dummies(data4,dtype=int)

# %%
display(data6)
# Out:
#       YEAR   JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP  ...  \
# 0     1901  49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1  332.6  ...
# 1     1902   0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7  666.2  ...
# 2     1903  12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7  339.0  ...
# 3     1904   9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1  820.4  ...
# 4     1905   1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5  297.0  ...
# ...    ...   ...    ...   ...    ...    ...    ...    ...    ...    ...  ...
# 4111  2011   5.1    2.8   3.1   85.9  107.2  153.6  350.2  254.0  255.2  ...
# 4112  2012  19.2    0.1   1.6   76.8   21.2  327.0  231.5  381.2  179.8  ...
# 4113  2013  26.2   34.4  37.5    5.3   88.3  426.2  296.4  154.4  180.0  ...
# 4114  2014  53.2   16.1   4.4   14.9   57.4  244.1  116.1  466.1  132.2  ...
# 4115  2015   2.2    0.5   3.7   87.1  133.1  296.6  257.5  146.4  160.4  ...
#
# ...

# %%
y=data6['ANNUAL']
x=data6.drop('ANNUAL',axis=1)

# %%
x
# Out:
#       YEAR   JAN    FEB   MAR    APR    MAY    JUN    JUL    AUG    SEP  ...  \
# 0     1901  49.2   87.1  29.2    2.3  528.8  517.5  365.1  481.1  332.6  ...
# 1     1902   0.0  159.8  12.2    0.0  446.1  537.1  228.9  753.7  666.2  ...
# 2     1903  12.7  144.0   0.0    1.0  235.1  479.9  728.4  326.7  339.0  ...
# 3     1904   9.4   14.7   0.0  202.4  304.5  495.1  502.0  160.1  820.4  ...
# 4     1905   1.3    0.0   3.3   26.9  279.5  628.7  368.7  330.5  297.0  ...
# ...    ...   ...    ...   ...    ...    ...    ...    ...    ...    ...  ...
# 4111  2011   5.1    2.8   3.1   85.9  107.2  153.6  350.2  254.0  255.2  ...
# 4112  2012  19.2    0.1   1.6   76.8   21.2  327.0  231.5  381.2  179.8  ...
# 4113  2013  26.2   34.4  37.5    5.3   88.3  426.2  296.4  154.4  180.0  ...
# 4114  2014  53.2   16.1   4.4   14.9   57.4  244.1  116.1  466.1  132.2  ...
# 4115  2015   2.2    0.5   3.7   87.1  133.1  296.6  257.5  146.4  160.4  ...
#
# ...

# %%
y
# Out:
# 0       3373.2
# 1       3520.7
# 2       2957.4
# 3       3079.6
# 4       2566.7
#          ...
# 4111    1533.7
# 4112    1405.5
# 4113    1426.3
# 4114    1395.0
# 4115    1642.9
# Name: ANNUAL, Length: 4116, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test
# Out:
#       YEAR   JAN   FEB    MAR   APR    MAY    JUN    JUL    AUG    SEP  ...  \
# 2647  1926  34.3   0.6    0.1   0.2   11.2   85.9  230.6  258.0  147.7  ...
# 842   1961   8.9  84.3    1.0   4.6   30.0  298.6  296.3  358.2  317.2  ...
# 2351  1975   0.0   0.0    0.7   0.0    0.1  156.0  219.5  449.6  318.5  ...
# 751   1985  24.2  35.0    4.7  16.4   52.9  195.4  305.7  460.9  335.2  ...
# 3626  1985   5.3   0.0    1.6  12.9   76.9  977.9  668.5  844.3  130.6  ...
# ...    ...   ...   ...    ...   ...    ...    ...    ...    ...    ...  ...
# 2057  1911  16.2   0.5    3.5   0.0    0.8  112.2  111.1  154.2  222.3  ...
# 2420  1929   5.1   0.0    0.0   3.1    0.5   39.6  268.4   63.2   11.5  ...
# 324   1903   6.5  40.5  139.8  45.5  159.9  458.6  300.2  470.6  366.1  ...
# 1905  1989   8.6   0.0    1.3   1.0    0.2   25.8   81.0  109.1   20.3  ...
# 1960  1929   3.6   1.5    0.0   4.0    6.9   50.9  270.8  194.0   34.4  ...
#
# ...

# %%
y_test
# Out:
# 2647     787.1
# 842     1560.5
# 2351    1192.7
# 751     1607.3
# 3626    3015.7
#          ...
# 2057     676.5
# 2420     421.8
# 324     2230.7
# 1905     248.1
# 1960     576.0
# Name: ANNUAL, Length: 824, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=reg.predict(x_test)
ypred
# Out:
# array([  774.80121992,  1544.59758106,  1174.87259313,  1592.88248401,
#         2957.56437323,  2780.57521387,  1091.73042418,  1150.48685843,
#         2905.29405192,   810.7466124 ,   566.16217366,   788.53301856,
#         3235.20452085,  1401.02729178,   866.92704112,   656.36504352,
#          523.85774105,   272.08252698,  2632.40301245,   788.68856367,
#          958.21563199,  2964.27264622,  1008.64363211,   754.51687014,
#         1005.93843103,  2924.49533198,  1065.12769932,  3272.67698973,
#         1128.15790978,  1382.40193434,   789.85025018,  2609.92214932,
#          820.64926477,   676.20942436,   707.57566564,  1252.47728057,
#         1508.70704426,   768.72586485,   636.27143964,  1091.47810673,
#          469.67625843,   931.06578019,  2629.35415703,   612.67428156,
#         1050.69172693,   581.08567337,  1011.83908019,  1320.44961555,
#         3151.44253786,   331.95918741,  2175.83393131,  1040.17403421,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# 0.9921649119742406

# %%
from sklearn.metrics import mean_squared_error 
mean_squared_error(ypred,y_test)
# Out:
# 6915.516192829372

# %%
Results=a.DataFrame(columns=['ANNUAL','PREDICTED'])
Results['ANNUAL']=y_test
Results['PREDICTED']=ypred
Results=Results.reset_index()
Results['YEAR']=Results.index
Results.head(15)
# Out:
#     index  ANNUAL    PREDICTED  YEAR
# 0    2647   787.1   774.801220     0
# 1     842  1560.5  1544.597581     1
# 2    2351  1192.7  1174.872593     2
# 3     751  1607.3  1592.882484     3
# 4    3626  3015.7  2957.564373     4
# 5     296  2771.2  2780.575214     5
# 6    1730  1102.7  1091.730424     6
# 7     869  1153.7  1150.486858     7
# 8     109  2904.6  2905.294052     8
# 9    1138   804.5   810.746612     9
# 10   2468   564.1   566.162174    10
# 11   3805   786.3   788.533019    11
# 12    184  3348.9  3235.204521    12
# 13   3286  1425.7  1401.027292    13
# 14   1350   847.8   866.927041    14

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='YEAR',y='ANNUAL',data=Results.head(15))
sns.lineplot(x='YEAR',y='PREDICTED',data=Results.head(15))
plt.plot()
# Out:
# []

# %%
data[['SUBDIVISION', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
       'AUG', 'SEP', 'OCT', 'NOV', 'DEC']].groupby("SUBDIVISION").mean().plot.barh(stacked=True,figsize=(13,6))
# Out:
# <Axes: ylabel='SUBDIVISION'>

# %%
cor_mat=data1.corr()
cor_mat
# Out:
#              YEAR       JAN       FEB       MAR       APR       MAY       JUN  \
# YEAR     1.000000 -0.056235 -0.022144  0.020338  0.008007  0.003594 -0.013594
# JAN     -0.056235  1.000000  0.456183  0.398502  0.209302  0.129622 -0.033725
# FEB     -0.022144  0.456183  1.000000  0.579819  0.367114  0.203062  0.033703
# MAR      0.020338  0.398502  0.579819  1.000000  0.556856  0.362815  0.165857
# APR      0.008007  0.209302  0.367114  0.556856  1.000000  0.650595  0.457091
# MAY      0.003594  0.129622  0.203062  0.362815  0.650595  1.000000  0.567618
# JUN     -0.013594 -0.033725  0.033703  0.165857  0.457091  0.567618  1.000000
# JUL     -0.016240 -0.051642  0.016235  0.097334  0.268097  0.332283  0.741285
# AUG      0.006442  0.011952  0.072159  0.135071  0.256168  0.329499  0.655142
# SEP     -0.006670  0.024289  0.080148  0.178904  0.382525  0.492378  0.551890
# OCT      0.002406  0.012374 -0.004581  0.086187  0.368886  0.529342  0.490393
# ...

# %%
sns.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidths=1,cmap='bwr')
# Out:
# <Axes: >
